# %% [markdown]
# # Lab20: Association Analysis
#
# In this lab we will be working on identifying *association rules*.  Association a way of identifying a combination of items that are associated with other items in the form of an IF-THEN type of rule:
#
#     X -> Y
#
# where X and Y are sets of items (goods, words, etc.).  The rule above asks if we purchase X then how often do we also purchase Y?

# %% [markdown]
# ## Install mlxtend
#
# We will be using the package `mlxtend` for our analysis.  This is a machine learning package (hence the ml) and has some features that overlap with SciKit Learn and other analysis pacakages.
#
# Using `Anaconda Navigator` install the `mlxtend` package.  It is on the `conda-forge` channel, so you will have to make sure that you have that set up as well.  (We did this back in Lab01.)

# %%
import pandas as pd

# TransactionEncoder will convert our data set to something
# the association-rule algorithm can use
from mlxtend.preprocessing import TransactionEncoder

# We will use the apriori module to generate a dataframe that
# we can use for association rule finding
from mlxtend.frequent_patterns import apriori

# We will use the association_rules module to generate
# our association rules from the apriori output data frame
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Load our groceries data set
#
# This is from [Kaggle](https://www.kaggle.com/datasets/heeraldedhia/groceries-dataset?resource=download).  It is a CSV file containing around 38000 purchases of people from grocery stores.
#
# Load and examine the file as a Pandas DataFrame.
#
# Use the `sort_values` method to sort first by CustomerID and then by date, and examine the resulting sorted DataFrame. You will note that the file appears to contain daily transactions for each customer.  We will assume that a customer's daily purchases constitute a single transaction.

# %%
fn_grocery = 'Groceries_dataset.csv'
df_raw = pd.read_csv(fn_grocery)

# %%
df_raw.info()
df_raw.head()
df_raw.sort_values(['Member_number' ,'Date'],inplace=True)
df_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB
#        Member_number        Date      itemDescription
# 4843            1000  15-03-2015              sausage
# 8395            1000  15-03-2015           whole milk
# 20992           1000  15-03-2015  semi-finished bread
# 24544           1000  15-03-2015               yogurt
# 13331           1000  24-06-2014           whole milk
# ...              ...         ...                  ...
# 3578            5000  10-02-2015                 soda
# 19727           5000  10-02-2015      root vegetables
# 34885           5000  10-02-2015  semi-finished bread
# 9340            5000  16-11-2014         bottled beer
# 25489           5000  16-11-2014     other vegetables
#
# [38765 rows x 3 columns]

# %% [markdown]
# ## Group the transactions
#
# Using `groupby` group each transaction by `Member_number` and `Date`.  This will give us one "row" with each purchase per customer per day.  We will use this in a moment to encode a new DataFrame for our `mlxtend`'s use.

# %%
df_grouped = df_raw.groupby(['Member_number','Date'])
df_grouped

# %% [markdown]
# ## Encode the grouped data frame
#
# Here we need to transform our dataset with the `Member_number` and `Date` index into a DataFrame that `mlxtend` can use to calculate the support of each transaction.
#
# The `agg` method will return a DataFrame.  We need to convert its output into a list of lists.

# %%
def make_transaction_list(x):
    '''
    Will return a list of the unique items
    in a particular grouping when used with
    the agg method as its function
    '''
    return x.unique()

# %%
# Use the agg method and make_transaction_list
# to return a list of unique items for each
# transaction
df_grouped['itemDescription'].agg(make_transaction_list) # gets data series back
df_transactions = df_grouped.agg(make_transaction_list) # gets data frame back

# %% [markdown]
# ## Convert to list of lists
#
# From the DataFrame you created using the `agg` function, turn the output Series into a list of lists.

# %%
list_trans = list(df_transactions['itemDescription'])
len(list_trans)
list_trans
# Out:
# [array(['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#        dtype=object),
#  array(['whole milk', 'pastry', 'salty snack'], dtype=object),
#  array(['canned beer', 'misc. beverages'], dtype=object),
#  array(['sausage', 'hygiene articles'], dtype=object),
#  array(['soda', 'pickled vegetables'], dtype=object),
#  array(['frankfurter', 'curd'], dtype=object),
#  array(['sausage', 'whole milk', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'soda'], dtype=object),
#  array(['beef', 'white bread'], dtype=object),
#  array(['frankfurter', 'soda', 'whipped/sour cream'], dtype=object),
#  array(['frozen vegetables', 'other vegetables'], dtype=object),
#  array(['butter', 'whole milk'], dtype=object),
#  array(['tropical fruit', 'sugar'], dtype=object),
#  array(['butter milk', 'specialty chocolate'], dtype=object),
#  array(['sausage', 'rolls/buns'], dtype=object),
#  array(['root vegetables', 'detergent'], dtype=object),
#  array(['frozen meals', 'dental care'], dtype=object),
#  array(['rolls/buns'], dtype=object),
#  array(['dish cleaner', 'cling film/bags'], dtype=object),
#  array(['canned beer', 'frozen fish'], dtype=object),
#  array(['other vegetables', 'hygiene articles'], dtype=object),
#  array(['pip fruit', 'whole milk', 'tropical fruit'], dtype=object),
#  array(['rolls/buns', 'red/blush wine', 'chocolate'], dtype=object),
#  array(['other vegetables', 'shopping bags'], dtype=object),
#  array(['whole milk', 'chocolate', 'packaged fruit/vegetables',
#         'rolls/buns'], dtype=object),
#  array(['root vegetables', 'whole milk', 'pastry'], dtype=object),
#  array(['rolls/buns'], dtype=object),
#  array(['whipped/sour cream', 'margarine'], dtype=object),
#  array(['bottled water', 'softener', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'rice'], dtype=object),
#  array(['shopping bags', 'skin care'], dtype=object),
#  array(['whole milk', 'frankfurter', 'chicken', 'flour', 'chocolate',
#         'bottled beer', 'rolls/buns'], dtype=object),
#  array(['hamburger meat', 'liquor (appetizer)', 'liver loaf', 'dessert'],
#        dtype=object),
#  array(['tropical fruit', 'soda', 'yogurt', 'root vegetables',
#         'domestic eggs', 'white wine', 'photo/film'], dtype=object),
#  array(['herbs', 'yogurt', 'newspapers'], dtype=object),
#  array(['tropical fruit', 'yogurt'], dtype=object),
#  array(['pastry', 'ketchup'], dtype=object),
#  array(['canned fish', 'cocoa drinks'], dtype=object),
#  array(['pip fruit', 'coffee', 'UHT-milk'], dtype=object),
#  array(['kitchen towels', 'sliced cheese'], dtype=object),
#  array(['bottled water', 'specialty bar'], dtype=object),
#  array(['frankfurter', 'bottled water'], dtype=object),
#  array(['pip fruit', 'candles', 'rolls/buns'], dtype=object),
#  array(['curd cheese', 'pastry'], dtype=object),
#  array(['whole milk', 'frankfurter', 'candles', 'grapes', 'herbs',
#         'other vegetables', 'yogurt'], dtype=object),
#  array(['citrus fruit', 'candy', 'bottled water', 'rolls/buns'],
#        dtype=object),
#  array(['frankfurter', 'yogurt'], dtype=object),
#  array(['tropical fruit', 'root vegetables', 'rolls/buns', 'onions',
#         'shopping bags'], dtype=object),
#  array(['frozen vegetables', 'brown bread'], dtype=object),
#  array(['processed cheese', 'whole milk'], dtype=object),
#  array(['frozen meals', 'whole milk'], dtype=object),
#  array(['white bread', 'meat', 'domestic eggs', 'roll products '],
#        dtype=object),
#  array(['root vegetables', 'mayonnaise'], dtype=object),
#  array(['other vegetables', 'mustard'], dtype=object),
#  array(['hard cheese', 'napkins', 'bottled water'], dtype=object),
#  array(['whole milk', 'candy'], dtype=object),
#  array(['tropical fruit', 'frozen vegetables'], dtype=object),
#  array(['mustard', 'whipped/sour cream'], dtype=object),
#  array(['whole milk', 'sausage', 'bottled beer', 'yogurt'], dtype=object),
#  array(['canned beer', 'cookware'], dtype=object),
#  array(['hamburger meat', 'butter milk'], dtype=object),
#  array(['whole milk', 'rolls/buns'], dtype=object),
#  array(['citrus fruit', 'whole milk'], dtype=object),
#  array(['salty snack', 'beef'], dtype=object),
#  array(['fruit/vegetable juice', 'rolls/buns', 'chocolate'], dtype=object),
#  array(['UHT-milk', 'bottled beer'], dtype=object),
#  array(['chicken', 'red/blush wine'], dtype=object),
#  array(['soft cheese', 'pip fruit'], dtype=object),
#  array(['rolls/buns', 'frankfurter', 'oil', 'pip fruit', 'mayonnaise'],
#        dtype=object),
#  array(['brown bread', 'pet care'], dtype=object),
#  array(['other vegetables', 'rolls/buns'], dtype=object),
#  array(['yogurt', 'beef'], dtype=object),
#  array(['other vegetables', 'root vegetables'], dtype=object),
#  array(['soda', 'dessert', 'shopping bags'], dtype=object),
#  array(['curd', 'long life bakery product'], dtype=object),
#  array(['beverages', 'domestic eggs'], dtype=object),
#  array(['butter milk', 'root vegetables'], dtype=object),
#  array(['berries', 'cake bar'], dtype=object),
#  array(['hamburger meat', 'red/blush wine'], dtype=object),
#  array(['canned beer', 'shopping bags'], dtype=object),
#  array(['canned beer', 'spices', 'rolls/buns', 'frozen fish'], dtype=object),
#  array(['frozen meals', 'butter', 'newspapers', 'yogurt'], dtype=object),
#  array(['rolls/buns', 'baking powder'], dtype=object),
#  array(['liquor', 'curd', 'yogurt', 'tropical fruit'], dtype=object),
#  array(['sliced cheese', 'butter'], dtype=object),
#  array(['sausage', 'fruit/vegetable juice'], dtype=object),
#  array(['beef', 'napkins'], dtype=object),
#  array(['whole milk', 'whipped/sour cream'], dtype=object),
#  array(['whipped/sour cream', 'root vegetables', 'rolls/buns',
#         'packaged fruit/vegetables'], dtype=object),
#  array(['domestic eggs', 'soda'], dtype=object),
#  array(['chicken', 'frozen meals'], dtype=object),
#  array(['male cosmetics', 'curd'], dtype=object),
#  array(['white bread', 'bottled beer', 'yogurt', 'berries'], dtype=object),
#  array(['sausage', 'whipped/sour cream', 'specialty bar'], dtype=object),
#  array(['fish', 'root vegetables', 'tropical fruit', 'other vegetables'],
#        dtype=object),
#  array(['coffee', 'shopping bags'], dtype=object),
#  array(['ham', 'cream cheese '], dtype=object),
#  array(['canned beer', 'UHT-milk'], dtype=object),
#  array(['sausage', 'dessert', 'rolls/buns', 'pickled vegetables'],
#        dtype=object),
#  array(['fruit/vegetable juice', 'salty snack', 'candy', 'dental care',
#         'butter'], dtype=object),
#  array(['root vegetables', 'long life bakery product'], dtype=object),
#  array(['citrus fruit', 'yogurt'], dtype=object),
#  array(['root vegetables', 'whipped/sour cream', 'canned beer'],
#        dtype=object),
#  array(['softener', 'salt', 'whole milk'], dtype=object),
#  array(['pork', 'hamburger meat'], dtype=object),
#  array(['rolls/buns', 'bottled water'], dtype=object),
#  array(['rolls/buns', 'red/blush wine'], dtype=object),
#  array(['onions', 'canned beer', 'flower (seeds)'], dtype=object),
#  array(['rolls/buns', 'sugar'], dtype=object),
#  array(['soda', 'butter'], dtype=object),
#  array(['specialty chocolate', 'root vegetables'], dtype=object),
#  array(['rolls/buns', 'baking powder', 'onions', 'bottled water'],
#        dtype=object),
#  array(['dessert', 'ham'], dtype=object),
#  array(['ice cream', 'pot plants'], dtype=object),
#  array(['other vegetables', 'berries'], dtype=object),
#  array(['beverages', 'cream cheese '], dtype=object),
#  array(['ice cream', 'whipped/sour cream'], dtype=object),
#  array(['berries', 'soda', 'butter', 'other vegetables', 'white bread',
#         'cream cheese '], dtype=object),
#  array(['yogurt', 'root vegetables'], dtype=object),
#  array(['white bread', 'whole milk', 'pastry', 'shopping bags'],
#        dtype=object),
#  array(['whipped/sour cream', 'newspapers'], dtype=object),
#  array(['frankfurter', 'pastry'], dtype=object),
#  array(['chicken', 'waffles'], dtype=object),
#  array(['fruit/vegetable juice', 'dessert'], dtype=object),
#  array(['sausage', 'snack products', 'rolls/buns'], dtype=object),
#  array(['tropical fruit', 'soda', 'rolls/buns'], dtype=object),
#  array(['tropical fruit', 'newspapers'], dtype=object),
#  array(['pip fruit', 'cling film/bags', 'yogurt', 'cat food'], dtype=object),
#  array(['bottled water', 'domestic eggs', 'frozen meals'], dtype=object),
#  array(['whole milk', 'newspapers'], dtype=object),
#  array(['pip fruit', 'white wine', 'white bread', 'salt'], dtype=object),
#  array(['sausage', 'frozen vegetables'], dtype=object),
#  array(['whole milk', 'yogurt', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'frozen vegetables'], dtype=object),
#  array(['fruit/vegetable juice', 'vinegar'], dtype=object),
#  array(['citrus fruit', 'shopping bags', 'chewing gum', 'cake bar'],
#        dtype=object),
#  array(['frankfurter', 'yogurt', 'canned beer'], dtype=object),
#  array(['tropical fruit', 'white bread', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'pip fruit', 'whipped/sour cream'], dtype=object),
#  array(['other vegetables', 'specialty chocolate'], dtype=object),
#  array(['Instant food products', 'whipped/sour cream', 'butter',
#         'cake bar'], dtype=object),
#  array(['sausage', 'pork', 'butter', 'whole milk', 'fruit/vegetable juice'],
#        dtype=object),
#  array(['pip fruit', 'herbs', 'frozen meals'], dtype=object),
#  array(['margarine', 'napkins'], dtype=object),
#  array(['salty snack', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'pasta', 'rolls/buns'], dtype=object),
#  array(['yogurt', 'rolls/buns'], dtype=object),
#  array(['root vegetables', 'white bread'], dtype=object),
#  array(['tropical fruit', 'chicken', 'onions', 'packaged fruit/vegetables'],
#        dtype=object),
#  array(['hamburger meat', 'yogurt'], dtype=object),
#  array(['prosecco', 'dessert'], dtype=object),
#  array(['chicken', 'frozen vegetables', 'candy'], dtype=object),
#  array(['tropical fruit', 'brown bread', 'whole milk'], dtype=object),
#  array(['beef', 'dessert'], dtype=object),
#  array(['whole milk', 'other vegetables'], dtype=object),
#  array(['citrus fruit', 'bottled water'], dtype=object),
#  array(['citrus fruit', 'rolls/buns', 'whole milk'], dtype=object),
#  array(['tropical fruit', 'sliced cheese'], dtype=object),
#  array(['napkins', 'whole milk', 'chocolate marshmallow'], dtype=object),
#  array(['tropical fruit', 'other vegetables'], dtype=object),
#  array(['root vegetables', 'curd'], dtype=object),
#  array(['fruit/vegetable juice', 'specialty chocolate',
#         'Instant food products'], dtype=object),
#  array(['root vegetables', 'yogurt', 'butter'], dtype=object),
#  array(['chicken', 'onions'], dtype=object),
#  array(['whole milk', 'pastry'], dtype=object),
#  array(['pork', 'bottled water'], dtype=object),
#  array(['curd', 'soda'], dtype=object),
#  array(['sweet spreads', 'butter'], dtype=object),
#  array(['pip fruit', 'soda'], dtype=object),
#  array(['rolls/buns', 'condensed milk', 'whole milk', 'soda'], dtype=object),
#  array(['rolls/buns', 'tropical fruit'], dtype=object),
#  array(['butter', 'whole milk'], dtype=object),
#  array(['white bread', 'candy'], dtype=object),
#  array(['frankfurter', 'herbs'], dtype=object),
#  array(['specialty bar', 'margarine'], dtype=object),
#  array(['meat', 'whole milk'], dtype=object),
#  array(['house keeping products', 'yogurt'], dtype=object),
#  array(['whipped/sour cream', 'hygiene articles'], dtype=object),
#  array(['UHT-milk', 'other vegetables', 'dishes'], dtype=object),
#  array(['waffles', 'beverages'], dtype=object),
#  array(['pasta', 'yogurt', 'cat food'], dtype=object),
#  array(['fish', 'tropical fruit', 'red/blush wine', 'cream cheese '],
#        dtype=object),
#  array(['other vegetables', 'soda', 'rolls/buns', 'dishes'], dtype=object),
#  array(['tropical fruit', 'other vegetables', 'hamburger meat', 'popcorn',
#         'female sanitary products'], dtype=object),
#  array(['hamburger meat', 'bottled beer'], dtype=object),
#  array(['pork', 'coffee', 'frozen vegetables'], dtype=object),
#  array(['shopping bags'], dtype=object),
#  array(['beef', 'shopping bags'], dtype=object),
#  array(['soda', 'hamburger meat'], dtype=object),
#  array(['butter milk', 'yogurt', 'margarine'], dtype=object),
#  array(['soda', 'whole milk'], dtype=object),
#  array(['root vegetables', 'grapes'], dtype=object),
#  array(['frankfurter', 'whipped/sour cream'], dtype=object),
#  array(['bottled water', 'chewing gum'], dtype=object),
#  array(['chicken', 'beverages', 'coffee'], dtype=object),
#  array(['pork', 'other vegetables', 'yogurt', 'shopping bags',
#         'soft cheese', 'detergent'], dtype=object),
#  array(['butter', 'dog food'], dtype=object),
#  array(['chicken', 'frozen vegetables'], dtype=object),
#  array(['hamburger meat', 'pastry'], dtype=object),
#  array(['other vegetables', 'whole milk'], dtype=object),
#  array(['waffles', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'sugar'], dtype=object),
#  array(['soda'], dtype=object),
#  array(['bottled beer', 'oil'], dtype=object),
#  array(['frankfurter', 'citrus fruit', 'margarine'], dtype=object),
#  array(['soda', 'fruit/vegetable juice'], dtype=object),
#  array(['photo/film', 'other vegetables'], dtype=object),
#  array(['pork', 'white wine'], dtype=object),
#  array(['bottled water', 'yogurt', 'newspapers', 'soda'], dtype=object),
#  array(['whipped/sour cream', 'meat spreads'], dtype=object),
#  array(['pip fruit', 'other vegetables'], dtype=object),
#  array(['ham', 'whole milk'], dtype=object),
#  array(['salty snack', 'pickled vegetables'], dtype=object),
#  array(['soda', 'domestic eggs', 'sliced cheese'], dtype=object),
#  array(['tropical fruit', 'UHT-milk'], dtype=object),
#  array(['sausage', 'bottled water'], dtype=object),
#  array(['yogurt', 'root vegetables'], dtype=object),
#  array(['root vegetables', 'other vegetables'], dtype=object),
#  array(['chicken', 'other vegetables'], dtype=object),
#  array(['dessert', 'spread cheese'], dtype=object),
#  array(['sausage', 'salty snack', 'cling film/bags'], dtype=object),
#  array(['whole milk', 'tropical fruit', 'root vegetables',
#         'Instant food products', 'margarine'], dtype=object),
#  array(['soda', 'fruit/vegetable juice', 'bottled beer'], dtype=object),
#  array(['beef', 'chocolate'], dtype=object),
#  array(['beverages', 'dessert'], dtype=object),
#  array(['whipped/sour cream', 'hard cheese'], dtype=object),
#  array(['ham', 'whipped/sour cream', 'ketchup'], dtype=object),
#  array(['white bread', 'frozen fruits'], dtype=object),
#  array(['tropical fruit', 'whole milk', 'other vegetables',
#         'long life bakery product'], dtype=object),
#  array(['other vegetables', 'yogurt', 'whole milk', 'butter',
#         'shopping bags'], dtype=object),
#  array(['whole milk', 'sauces'], dtype=object),
#  array(['whole milk', 'citrus fruit'], dtype=object),
#  array(['rolls/buns', 'candy'], dtype=object),
#  array(['root vegetables', 'whole milk'], dtype=object),
#  array(['cream cheese ', 'rolls/buns'], dtype=object),
#  array(['long life bakery product', 'root vegetables', 'other vegetables'],
#        dtype=object),
#  array(['tropical fruit', 'rolls/buns'], dtype=object),
#  array(['frankfurter', 'tropical fruit'], dtype=object),
#  array(['tropical fruit', 'whole milk', 'long life bakery product', 'rum'],
#        dtype=object),
#  array(['hamburger meat', 'soda'], dtype=object),
#  array(['red/blush wine', 'frozen fish'], dtype=object),
#  array(['beef', 'dessert'], dtype=object),
#  array(['root vegetables', 'bottled beer'], dtype=object),
#  array(['oil', 'shopping bags'], dtype=object),
#  array(['whole milk', 'other vegetables'], dtype=object),
#  array(['whole milk', 'tropical fruit'], dtype=object),
#  array(['hamburger meat', 'pork'], dtype=object),
#  array(['rolls/buns', 'tropical fruit', 'coffee', 'chocolate'],
#        dtype=object),
#  array(['pork', 'spread cheese'], dtype=object),
#  array(['soda', 'yogurt'], dtype=object),
#  array(['salt', 'domestic eggs'], dtype=object),
#  array(['pork', 'rolls/buns'], dtype=object),
#  array(['brown bread', 'fruit/vegetable juice'], dtype=object),
#  array(['bottled beer', 'tropical fruit', 'sliced cheese', 'dishes'],
#        dtype=object),
#  array(['cream cheese ', 'newspapers'], dtype=object),
#  array(['citrus fruit', 'red/blush wine'], dtype=object),
#  array(['yogurt', 'roll products ', 'fruit/vegetable juice'], dtype=object),
#  array(['ham', 'other vegetables'], dtype=object),
#  array(['frankfurter', 'canned beer'], dtype=object),
#  array(['finished products', 'brown bread', 'dishes'], dtype=object),
#  array(['yogurt', 'bottled water', 'domestic eggs'], dtype=object),
#  array(['pip fruit', 'curd', 'prosecco'], dtype=object),
#  array(['brown bread', 'salt'], dtype=object),
#  array(['semi-finished bread', 'ketchup'], dtype=object),
#  array(['oil', 'shopping bags'], dtype=object),
#  array(['fruit/vegetable juice', 'flower (seeds)'], dtype=object),
#  array(['misc. beverages', 'instant coffee'], dtype=object),
#  array(['detergent', 'candy'], dtype=object),
#  array(['UHT-milk', 'canned fish'], dtype=object),
#  array(['frankfurter', 'citrus fruit', 'bottled water',
#         'fruit/vegetable juice'], dtype=object),
#  array(['frankfurter', 'frozen meals', 'dishes'], dtype=object),
#  array(['pip fruit', 'rolls/buns'], dtype=object),
#  array(['sausage', 'butter', 'bottled water'], dtype=object),
#  array(['frankfurter', 'chicken', 'butter', 'bottled water'], dtype=object),
#  array(['ham', 'whole milk', 'coffee'], dtype=object),
#  array(['sausage', 'brown bread'], dtype=object),
#  array(['other vegetables', 'butter'], dtype=object),
#  array(['tropical fruit', 'soda'], dtype=object),
#  array(['pastry', 'pasta'], dtype=object),
#  array(['white bread', 'brown bread'], dtype=object),
#  array(['canned beer', 'rolls/buns', 'artif. sweetener', 'soda'],
#        dtype=object),
#  array(['rolls/buns', 'root vegetables'], dtype=object),
#  array(['chicken', 'soda'], dtype=object),
#  array(['frankfurter', 'curd', 'white bread', 'rolls/buns', 'coffee'],
#        dtype=object),
#  array(['red/blush wine', 'bottled water', 'sweet spreads'], dtype=object),
#  array(['rolls/buns', 'onions', 'napkins'], dtype=object),
#  array(['canned beer', 'soda'], dtype=object),
#  array(['root vegetables', 'frozen vegetables', 'pet care'], dtype=object),
#  array(['specialty bar', 'tropical fruit', 'yogurt', 'bottled beer',
#         'baking powder'], dtype=object),
#  array(['other vegetables', 'frankfurter', 'newspapers', 'whole milk',
#         'pastry'], dtype=object),
#  array(['beverages', 'yogurt'], dtype=object),
#  array(['tropical fruit', 'whole milk'], dtype=object),
#  array(['coffee', 'butter milk'], dtype=object),
#  array(['beef', 'margarine', 'other vegetables'], dtype=object),
#  array(['bottled water', 'hygiene articles'], dtype=object),
#  array(['pork', 'sliced cheese'], dtype=object),
#  array(['specialty chocolate', 'soda', 'bathroom cleaner'], dtype=object),
#  array(['hamburger meat', 'whole milk'], dtype=object),
#  array(['pip fruit', 'other vegetables'], dtype=object),
#  array(['root vegetables', 'citrus fruit'], dtype=object),
#  array(['other vegetables', 'shopping bags', 'soda'], dtype=object),
#  array(['yogurt', 'newspapers'], dtype=object),
#  array(['ice cream', 'whipped/sour cream'], dtype=object),
#  array(['other vegetables', 'beef', 'soda', 'curd', 'butter'], dtype=object),
#  array(['canned beer', 'herbs', 'margarine'], dtype=object),
#  array(['rolls/buns', 'soda'], dtype=object),
#  array(['rolls/buns', 'citrus fruit'], dtype=object),
#  array(['coffee', 'berries'], dtype=object),
#  array(['ham', 'white bread'], dtype=object),
#  array(['herbs', 'pot plants', 'cake bar'], dtype=object),
#  array(['soda', 'flower (seeds)', 'jam'], dtype=object),
#  array(['sausage', 'pip fruit', 'chocolate'], dtype=object),
#  array(['specialty chocolate', 'white bread'], dtype=object),
#  array(['whole milk'], dtype=object),
#  array(['other vegetables', 'whole milk'], dtype=object),
#  array(['sausage', 'beverages'], dtype=object),
#  array(['whole milk', 'hard cheese'], dtype=object),
#  array(['yogurt', 'berries'], dtype=object),
#  array(['tropical fruit', 'meat', 'other vegetables', 'domestic eggs',
#         'baking powder'], dtype=object),
#  array(['yogurt', 'sauces'], dtype=object),
#  array(['beef', 'yogurt'], dtype=object),
#  array(['ice cream', 'whole milk'], dtype=object),
#  array(['sausage', 'whisky', 'specialty chocolate', 'dishes', 'yogurt',
#         'napkins', 'detergent', 'pastry'], dtype=object),
#  array(['photo/film', 'shopping bags'], dtype=object),
#  array(['frankfurter', 'other vegetables', 'bottled beer'], dtype=object),
#  array(['yogurt', 'newspapers'], dtype=object),
#  array(['root vegetables', 'soda', 'specialty bar', 'other vegetables',
#         'frozen vegetables'], dtype=object),
#  array(['rolls/buns', 'grapes', 'bottled beer', 'sausage', 'salty snack',
#         'Instant food products', 'domestic eggs', 'bottled water'],
#        dtype=object),
#  array(['dessert', 'domestic eggs'], dtype=object),
#  array(['sausage', 'tropical fruit', 'misc. beverages', 'root vegetables'],
#        dtype=object),
#  array(['sausage', 'whole milk'], dtype=object),
#  array(['whole milk', 'brown bread'], dtype=object),
#  array(['hamburger meat', 'detergent', 'flour'], dtype=object),
#  array(['tropical fruit', 'soda'], dtype=object),
#  array(['newspapers', 'salty snack'], dtype=object),
#  array(['pasta', 'whole milk', 'waffles'], dtype=object),
#  array(['chocolate marshmallow', 'other vegetables'], dtype=object),
#  array(['pickled vegetables', 'flour'], dtype=object),
#  array(['yogurt', 'shopping bags'], dtype=object),
#  array(['packaged fruit/vegetables', 'bottled water', 'pork',
#         'domestic eggs'], dtype=object),
#  array(['pip fruit', 'fruit/vegetable juice'], dtype=object),
#  array(['tropical fruit', 'whole milk', 'soda', 'curd'], dtype=object),
#  array(['shopping bags', 'root vegetables'], dtype=object),
#  array(['whipped/sour cream', 'curd', 'shopping bags'], dtype=object),
#  array(['sausage', 'whole milk', 'cake bar'], dtype=object),
#  array(['frankfurter', 'whipped/sour cream', 'bottled water'], dtype=object),
#  array(['hard cheese', 'whole milk'], dtype=object),
#  array(['tropical fruit', 'citrus fruit', 'yogurt', 'frankfurter',
#         'specialty chocolate', 'hard cheese', 'whole milk', 'canned beer'],
#        dtype=object),
#  array(['canned beer', 'napkins', 'rolls/buns'], dtype=object),
#  array(['grapes', 'other vegetables'], dtype=object),
#  array(['rolls/buns', 'shopping bags', 'cat food'], dtype=object),
#  array(['tropical fruit', 'candy'], dtype=object),
#  array(['citrus fruit', 'dessert'], dtype=object),
#  array(['root vegetables', 'frozen vegetables', 'bottled water',
#         'cat food'], dtype=object),
#  array(['spread cheese', 'pork'], dtype=object),
#  array(['pip fruit', 'brown bread'], dtype=object),
#  array(['root vegetables', 'instant coffee'], dtype=object),
#  array(['soda', 'hygiene articles', 'grapes', 'pudding powder',
#         'butter milk', 'butter'], dtype=object),
#  array(['whole milk', 'yogurt'], dtype=object),
#  array(['hamburger meat', 'pasta'], dtype=object),
#  array(['whole milk', 'processed cheese'], dtype=object),
#  array(['brown bread', 'sparkling wine'], dtype=object),
#  array(['rolls/buns', 'other vegetables', 'whipped/sour cream'],
#        dtype=object),
#  array(['candy', 'white wine'], dtype=object),
#  array(['root vegetables', 'frozen vegetables'], dtype=object),
#  array(['other vegetables', 'white bread', 'detergent'], dtype=object),
#  array(['yogurt', 'beverages', 'brown bread'], dtype=object),
#  array(['ice cream', 'herbs'], dtype=object),
#  array(['cream', 'yogurt'], dtype=object),
#  array(['chicken', 'pastry', 'candles'], dtype=object),
#  array(['waffles', 'hygiene articles', 'tea'], dtype=object),
#  array(['yogurt', 'other vegetables', 'rolls/buns', 'herbs'], dtype=object),
#  array(['yogurt', 'root vegetables'], dtype=object),
#  array(['domestic eggs', 'yogurt'], dtype=object),
#  array(['pork', 'whole milk'], dtype=object),
#  array(['other vegetables', 'white bread'], dtype=object),
#  array(['bottled water', 'yogurt', 'tropical fruit', 'whole milk'],
#        dtype=object),
#  array(['citrus fruit', 'misc. beverages'], dtype=object),
#  array(['liver loaf', 'chicken', 'rolls/buns', 'spread cheese',
#         'shopping bags'], dtype=object),
#  array(['citrus fruit', 'misc. beverages'], dtype=object),
#  array(['whole milk', 'pastry'], dtype=object),
#  array(['onions', 'newspapers'], dtype=object),
#  array(['beef', 'specialty fat', 'newspapers'], dtype=object),
#  array(['rolls/buns', 'semi-finished bread'], dtype=object),
#  array(['shopping bags', 'rolls/buns'], dtype=object),
#  array(['pastry', 'canned beer', 'whipped/sour cream', 'grapes'],
#        dtype=object),
#  array(['salty snack', 'pastry', 'oil'], dtype=object),
#  array(['frozen potato products', 'specialty cheese'], dtype=object),
#  array(['brown bread', 'whole milk', 'shopping bags'], dtype=object),
#  array(['citrus fruit', 'frozen vegetables', 'margarine'], dtype=object),
#  array(['curd', 'sugar'], dtype=object),
#  array(['chocolate', 'whole milk'], dtype=object),
#  array(['pip fruit', 'salty snack', 'pastry'], dtype=object),
#  array(['pip fruit', 'margarine'], dtype=object),
#  array(['ham', 'yogurt'], dtype=object),
#  array(['soda', 'salty snack'], dtype=object),
#  array(['bottled water', 'chocolate'], dtype=object),
#  array(['pastry', 'baking powder', 'butter', 'margarine', 'curd', 'dishes'],
#        dtype=object),
#  array(['whole milk', 'soda'], dtype=object),
#  array(['pickled vegetables', 'liquor'], dtype=object),
#  array(['margarine', 'yogurt'], dtype=object),
#  array(['whole milk', 'frozen vegetables', 'soda', 'UHT-milk'],
#        dtype=object),
#  array(['other vegetables', 'whipped/sour cream'], dtype=object),
#  array(['beef', 'semi-finished bread'], dtype=object),
#  array(['bottled water', 'flour', 'sugar'], dtype=object),
#  array(['dish cleaner', 'ice cream', 'jam', 'newspapers'], dtype=object),
#  array(['curd', 'canned beer'], dtype=object),
#  array(['bottled beer', 'specialty bar', 'baking powder'], dtype=object),
#  array(['whole milk', 'yogurt', 'newspapers'], dtype=object),
#  array(['pork', 'pudding powder', 'domestic eggs'], dtype=object),
#  array(['root vegetables', 'shopping bags'], dtype=object),
#  array(['misc. beverages', 'UHT-milk', 'white bread'], dtype=object),
#  array(['dog food', 'sausage', 'dessert', 'shopping bags'], dtype=object),
#  array(['root vegetables', 'citrus fruit'], dtype=object),
#  array(['chocolate', 'brown bread', 'salty snack'], dtype=object),
#  array(['chicken', 'shopping bags'], dtype=object),
#  array(['other vegetables', 'butter'], dtype=object),
#  array(['whipped/sour cream', 'yogurt'], dtype=object),
#  array(['other vegetables', 'yogurt'], dtype=object),
#  array(['turkey', 'root vegetables'], dtype=object),
#  array(['other vegetables', 'napkins'], dtype=object),
#  array(['newspapers', 'white bread', 'rolls/buns', 'beverages'],
#        dtype=object),
#  array(['other vegetables', 'zwieback'], dtype=object),
#  array(['brown bread', 'butter milk', 'canned vegetables', 'soda'],
#        dtype=object),
#  array(['chicken', 'bottled water'], dtype=object),
#  array(['brown bread', 'soda'], dtype=object),
#  array(['other vegetables', 'cream cheese ', 'liquor', 'root vegetables',
#         'newspapers', 'hard cheese'], dtype=object),
#  array(['frankfurter', 'rolls/buns'], dtype=object),
#  array(['meat', 'whole milk', 'whipped/sour cream'], dtype=object),
#  array(['bottled beer', 'frozen vegetables', 'sliced cheese'], dtype=object),
#  array(['pip fruit', 'processed cheese', 'canned beer'], dtype=object),
#  array(['berries', 'condensed milk'], dtype=object),
#  array(['house keeping products', 'rolls/buns', 'pickled vegetables',
#         'curd'], dtype=object),
#  array(['whole milk', 'hair spray', 'butter', 'pastry'], dtype=object),
#  array(['ham', 'yogurt'], dtype=object),
#  array(['grapes', 'whole milk'], dtype=object),
#  array(['meat', 'other vegetables'], dtype=object),
#  array(['other vegetables', 'specialty bar'], dtype=object),
#  array(['soda', 'UHT-milk', 'newspapers', 'white bread'], dtype=object),
#  array(['citrus fruit', 'brown bread'], dtype=object),
#  array(['tropical fruit', 'sugar'], dtype=object),
#  array(['pastry', 'condensed milk', 'rice', 'tropical fruit',
#         'chocolate marshmallow'], dtype=object),
#  array(['coffee', 'shopping bags'], dtype=object),
#  array(['bottled water', 'citrus fruit'], dtype=object),
#  array(['root vegetables', 'frozen vegetables'], dtype=object),
#  array(['chicken', 'dishes'], dtype=object),
#  array(['rolls/buns', 'oil', 'yogurt'], dtype=object),
#  array(['pork', 'soda', 'canned vegetables'], dtype=object),
#  array(['pip fruit', 'whole milk'], dtype=object),
#  array(['frozen vegetables', 'rolls/buns', 'cling film/bags'], dtype=object),
#  array(['bottled beer', 'hygiene articles'], dtype=object),
#  array(['yogurt', 'soda'], dtype=object),
#  array(['rolls/buns', 'margarine'], dtype=object),
#  array(['condensed milk', 'shopping bags'], dtype=object),
#  array(['popcorn', 'citrus fruit'], dtype=object),
#  array(['sausage', 'pastry'], dtype=object),
#  array(['root vegetables', 'margarine', 'rolls/buns'], dtype=object),
#  array(['rolls/buns', 'whipped/sour cream'], dtype=object),
#  array(['newspapers', 'pork', 'root vegetables', 'napkins'], dtype=object),
#  array(['misc. beverages', 'whole milk', 'long life bakery product'],
#        dtype=object),
#  array(['citrus fruit', 'soda'], dtype=object),
#  array(['soda', 'roll products '], dtype=object),
#  array(['frankfurter', 'rolls/buns', 'shopping bags', 'margarine'],
#        dtype=object),
#  array(['other vegetables', 'butter', 'pastry', 'UHT-milk'], dtype=object),
#  array(['meat', 'coffee'], dtype=object),
#  array(['frankfurter', 'white bread'], dtype=object),
#  array(['liquor', 'domestic eggs'], dtype=object),
#  array(['specialty bar', 'soda', 'frozen vegetables'], dtype=object),
#  array(['grapes', 'frozen meals', 'flower (seeds)'], dtype=object),
#  array(['tea', 'yogurt', 'shopping bags', 'brown bread'], dtype=object),
#  array(['flower (seeds)', 'white wine'], dtype=object),
#  array(['cream cheese ', 'specialty chocolate'], dtype=object),
#  array(['whole milk', 'baking powder'], dtype=object),
#  array(['margarine', 'soda'], dtype=object),
#  array(['tropical fruit', 'cream cheese '], dtype=object),
#  array(['yogurt', 'softener'], dtype=object),
#  array(['bottled water', 'frankfurter', 'dessert', 'root vegetables'],
#        dtype=object),
#  array(['other vegetables', 'semi-finished bread', 'rolls/buns',
#         'shopping bags', 'salty snack'], dtype=object),
#  array(['soda', 'whole milk'], dtype=object),
#  array(['bottled beer', 'whole milk'], dtype=object),
#  array(['yogurt', 'pastry'], dtype=object),
#  array(['curd', 'domestic eggs'], dtype=object),
#  array(['coffee', 'shopping bags'], dtype=object),
#  array(['sausage', 'rolls/buns', 'rice'], dtype=object),
#  array(['pork', 'whole milk', 'napkins'], dtype=object),
#  array(['other vegetables', 'oil'], dtype=object),
#  array(['pastry', 'brown bread', 'yogurt'], dtype=object),
#  array(['cream cheese ', 'newspapers'], dtype=object),
#  array(['sausage', 'shopping bags', 'soda', 'butter', 'dessert'],
#        dtype=object),
#  array(['hard cheese', 'butter'], dtype=object),
#  array(['whole milk', 'other vegetables'], dtype=object),
#  array(['citrus fruit', 'flower (seeds)'], dtype=object),
#  array(['tropical fruit', 'butter milk', 'brown bread'], dtype=object),
#  array(['tropical fruit', 'whole milk'], dtype=object),
#  array(['rolls/buns', 'fruit/vegetable juice'], dtype=object),
#  array(['herbs', 'citrus fruit'], dtype=object),
#  array(['root vegetables', 'butter milk'], dtype=object),
#  array(['instant coffee', 'shopping bags'], dtype=object),
#  array(['tropical fruit', 'other vegetables'], dtype=object),
#  array(['other vegetables', 'beef'], dtype=object),
#  array(['nut snack', 'canned beer'], dtype=object),
#  array(['whole milk', 'other vegetables', 'sugar'], dtype=object),
#  array(['whole milk', 'root vegetables'], dtype=object),
#  array(['citrus fruit', 'napkins'], dtype=object),
#  array(['rolls/buns', 'butter milk'], dtype=object),
#  array(['rolls/buns', 'brown bread', 'canned beer'], dtype=object),
#  array(['tropical fruit', 'soft cheese'], dtype=object),
#  array(['tropical fruit', 'misc. beverages'], dtype=object),
#  array(['pork', 'pickled vegetables'], dtype=object),
#  array(['photo/film', 'frankfurter', 'other vegetables', 'curd', 'waffles'],
#        dtype=object),
#  array(['pip fruit', 'other vegetables', 'cling film/bags'], dtype=object),
#  array(['rolls/buns', 'whole milk', 'soda'], dtype=object),
#  array(['tropical fruit', 'yogurt'], dtype=object),
#  array(['cat food', 'rolls/buns'], dtype=object),
#  array(['berries', 'white bread'], dtype=object),
#  array(['rolls/buns', 'soda'], dtype=object),
#  array(['chicken', 'brown bread'], dtype=object),
#  array(['other vegetables', 'napkins'], dtype=object),
#  array(['newspapers', 'soups'], dtype=object),
#  array(['UHT-milk', 'soda'], dtype=object),
#  array(['pork', 'soda'], dtype=object),
#  array(['oil', 'pickled vegetables'], dtype=object),
#  array(['soda', 'whole milk', 'sugar'], dtype=object),
#  array(['misc. beverages', 'spread cheese'], dtype=object),
#  array(['meat', 'whole milk'], dtype=object),
#  array(['pork', 'domestic eggs'], dtype=object),
#  array(['root vegetables', 'coffee'], dtype=object),
#  array(['canned beer', 'fish'], dtype=object),
#  array(['hard cheese', 'root vegetables', 'white bread'], dtype=object),
#  array(['chicken', 'domestic eggs', 'white bread'], dtype=object),
#  array(['soda', 'whipped/sour cream'], dtype=object),
#  array(['brown bread', 'other vegetables'], dtype=object),
#  array(['tropical fruit', 'root vegetables'], dtype=object),
#  array(['bottled beer', 'soda'], dtype=object),
#  array(['whole milk', 'bottled beer'], dtype=object),
#  array(['bottled water', 'shopping bags', 'waffles'], dtype=object),
#  array(['pork', 'margarine'], dtype=object),
#  array(['frozen vegetables', 'pip fruit', 'root vegetables', 'cereals'],
#        dtype=object),
#  array(['yogurt', 'soda'], dtype=object),
#  array(['other vegetables', 'berries', 'candy', 'sliced cheese'],
#        dtype=object),
#  array(['curd', 'soft cheese'], dtype=object),
#  array(['soda', 'whole milk'], dtype=object),
#  array(['frozen meals', 'detergent'], dtype=object),
#  array(['specialty chocolate', 'canned fish'], dtype=object),
#  array(['soda', 'other vegetables'], dtype=object),
#  array(['pork', 'tropical fruit'], dtype=object),
#  array(['pork', 'yogurt'], dtype=object),
#  array(['yogurt', 'sausage', 'whole milk', 'shopping bags', 'white bread',
#         'dog food', 'baking powder', 'sliced cheese'], dtype=object),
#  array(['soda', 'other vegetables'], dtype=object),
#  array(['root vegetables', 'soda', 'long life bakery product'],
#        dtype=object),
#  array(['soda', 'bottled beer', 'chicken', 'yogurt'], dtype=object),
#  array(['seasonal products', 'frozen vegetables', 'yogurt'], dtype=object),
#  array(['other vegetables', 'fruit/vegetable juice'], dtype=object),
#  array(['long life bakery product', 'rolls/buns', 'UHT-milk',
#         'bottled water'], dtype=object),
#  array(['canned beer', 'sugar'], dtype=object),
#  array(['pip fruit', 'berries'], dtype=object),
#  array(['curd', 'soft cheese'], dtype=object),
#  array(['berries', 'pip fruit', 'pastry'], dtype=object),
#  array(['whole milk', 'rolls/buns'], dtype=object),
#  array(['pork', 'domestic eggs'], dtype=object),
#  array(['soda', 'frozen meals'], dtype=object),
#  array(['curd cheese', 'soda'], dtype=object),
#  array(['whole milk', 'grapes'], dtype=object),
#  array(['chewing gum', 'whole milk', 'bottled beer', 'ready soups'],
#        dtype=object),
#  array(['butter', 'ice cream'], dtype=object),
#  array(['chicken', 'cake bar'], dtype=object),
#  array(['frankfurter', 'soft cheese', 'mustard'], dtype=object),
#  array(['tropical fruit', 'rolls/buns', 'canned beer', 'dish cleaner'],
#        dtype=object),
#  array(['root vegetables', 'other vegetables', 'frozen vegetables'],
#        dtype=object),
#  array(['female sanitary products', 'rolls/buns'], dtype=object),
#  array(['citrus fruit', 'sausage', 'whole milk', 'canned beer'],
#        dtype=object),
#  array(['whole milk', 'sausage', 'pet care', 'yogurt'], dtype=object),
#  array(['whole milk', 'house keeping products'], dtype=object),
#  array(['frankfurter', 'brandy'], dtype=object),
#  array(['berries', 'other vegetables'], dtype=object),
#  array(['tropical fruit', 'UHT-milk', 'napkins', 'whole milk'],
#        dtype=object),
#  array(['beef', 'curd', 'frozen meals'], dtype=object),
#  array(['rolls/buns', 'other vegetables', 'butter', 'root vegetables'],
#        dtype=object),
#  array(['whole milk', 'bottled water'], dtype=object),
#  array(['yogurt', 'citrus fruit'], dtype=object),
#  array(['whole milk', 'cream cheese '], dtype=object),
#  array(['frozen vegetables', 'domestic eggs'], dtype=object),
#  array(['citrus fruit', 'soda'], dtype=object),
#  array(['citrus fruit', 'light bulbs'], dtype=object),
#  array(['yogurt', 'whole milk'], dtype=object),
#  array(['butter', 'chewing gum'], dtype=object),
#  array(['whole milk', 'root vegetables'], dtype=object),
#  array(['pip fruit', 'tropical fruit', 'mustard'], dtype=object),
#  array(['domestic eggs', 'beef', 'coffee', 'bottled beer'], dtype=object),
#  array(['shopping bags', 'frozen meals'], dtype=object),
#  array(['other vegetables', 'yogurt', 'whole milk', 'spread cheese'],
#        dtype=object),
#  array(['beef', 'newspapers', 'bottled beer'], dtype=object),
#  array(['misc. beverages', 'coffee'], dtype=object),
#  array(['canned beer', 'citrus fruit'], dtype=object),
#  array(['white bread', 'yogurt'], dtype=object),
#  array(['red/blush wine', 'salty snack'], dtype=object),
#  array(['canned beer', 'berries', 'male cosmetics',
#         'fruit/vegetable juice'], dtype=object),
#  array(['sausage', 'bottled water'], dtype=object),
#  array(['whole milk', 'beef', 'citrus fruit', 'newspapers',
#         'bottled water'], dtype=object),
#  array(['white bread', 'frozen vegetables'], dtype=object),
#  array(['other vegetables', 'sliced cheese'], dtype=object),
#  array(['whole milk', 'root vegetables', 'canned vegetables'], dtype=object),
#  array(['beef', 'house keeping products'], dtype=object),
#  array(['frozen vegetables', 'whole milk'], dtype=object),
#  array(['pork', 'packaged fruit/vegetables', 'chocolate'], dtype=object),
#  array(['curd', 'spices'], dtype=object),
#  array(['bottled water', 'tropical fruit'], dtype=object),
#  array(['root vegetables', 'brown bread'], dtype=object),
#  array(['rolls/buns', 'other vegetables'], dtype=object),
#  array(['coffee', 'domestic eggs'], dtype=object),
#  array(['frankfurter', 'frozen vegetables'], dtype=object),
#  array(['bottled beer', 'whole milk', 'UHT-milk', 'chocolate'],
#        dtype=object),
#  array(['sweet spreads', 'herbs', 'long life bakery product'], dtype=object),
#  array(['soda', 'detergent'], dtype=object),
#  array(['soda', 'margarine'], dtype=object),
#  array(['liquor', 'bottled water'], dtype=object),
#  array(['napkins', 'cleaner'], dtype=object),
#  array(['other vegetables', 'rolls/buns'], dtype=object),
#  array(['napkins'], dtype=object),
#  array(['cake bar', 'bottled beer'], dtype=object),
#  array(['waffles', 'whole milk', 'other vegetables', 'white bread'],
#        dtype=object),
#  array(['finished products', 'newspapers', 'whipped/sour cream'],
#        dtype=object),
#  array(['chicken', 'pip fruit'], dtype=object),
#  array(['chocolate', 'shopping bags'], dtype=object),
#  array(['citrus fruit', 'whipped/sour cream'], dtype=object),
#  array(['whole milk', 'turkey', 'pork', 'dog food', 'rolls/buns', 'soda',
#         'bottled water'], dtype=object),
#  array(['pip fruit', 'whipped/sour cream'], dtype=object),
#  array(['whole milk', 'sparkling wine'], dtype=object),
#  array(['whole milk', 'canned beer'], dtype=object),
#  array(['soda', 'whipped/sour cream'], dtype=object),
#  array(['other vegetables', 'soda'], dtype=object),
#  array(['brown bread', 'pasta'], dtype=object),
#  array(['bottled water', 'onions'], dtype=object),
#  array(['specialty chocolate', 'beverages'], dtype=object),
#  array(['bottled beer', 'fruit/vegetable juice', 'rolls/buns'],
#        dtype=object),
#  array(['specialty bar', 'newspapers'], dtype=object),
#  array(['rolls/buns', 'margarine'], dtype=object),
#  array(['hard cheese', 'rolls/buns'], dtype=object),
#  array(['rolls/buns', 'soft cheese', 'fruit/vegetable juice'], dtype=object),
#  array(['baking powder', 'pickled vegetables'], dtype=object),
#  array(['pip fruit', 'whipped/sour cream'], dtype=object),
#  array(['citrus fruit', 'syrup'], dtype=object),
#  array(['root vegetables', 'cling film/bags'], dtype=object),
#  array(['hamburger meat', 'other vegetables'], dtype=object),
#  array(['whole milk', 'citrus fruit', 'shopping bags', 'white wine',
#         'soda', 'yogurt'], dtype=object),
#  array(['pasta', 'oil'], dtype=object),
#  array(['citrus fruit', 'brown bread', 'specialty chocolate'], dtype=object),
#  array(['bottled water', 'yogurt', 'beef', 'berries', 'chocolate',
#         'butter'], dtype=object),
#  array(['hard cheese', 'sugar', 'bottled water'], dtype=object),
#  array(['soda', 'whole milk'], dtype=object),
#  array(['tropical fruit', 'other vegetables'], dtype=object),
#  array(['pastry', 'other vegetables'], dtype=object),
#  array(['frozen potato products', 'domestic eggs', 'curd cheese'],
#        dtype=object),
#  array(['whole milk', 'tropical fruit'], dtype=object),
#  array(['rolls/buns', 'canned beer', 'brown bread', 'dessert'],
#        dtype=object),
#  array(['tropical fruit', 'shopping bags'], dtype=object),
#  array(['bottled water', 'chocolate', 'jam'], dtype=object),
#  array(['other vegetables', 'ice cream', 'pork', 'salt'], dtype=object),
#  array(['oil', 'coffee'], dtype=object),
#  array(['cereals', 'soda'], dtype=object),
#  array(['chicken', 'frozen meals', 'napkins'], dtype=object),
#  array(['frozen potato products', 'whole milk'], dtype=object),
#  array(['citrus fruit', 'white bread'], dtype=object),
#  array(['bottled beer', 'oil', 'whole milk', 'dishes'], dtype=object),
#  array(['sausage', 'root vegetables'], dtype=object),
#  array(['white bread', 'mayonnaise'], dtype=object),
#  array(['ice cream', 'hamburger meat', 'shopping bags', 'whole milk',
#         'soft cheese'], dtype=object),
#  array(['candy', 'baking powder', 'canned fish'], dtype=object),
#  array(['butter', 'mustard'], dtype=object),
#  array(['beef', 'butter milk'], dtype=object),
#  array(['hamburger meat', 'pip fruit'], dtype=object),
#  array(['rolls/buns', 'red/blush wine'], dtype=object),
#  array(['sausage', 'domestic eggs'], dtype=object),
#  array(['sausage', 'bottled beer', 'dessert', 'butter', 'cream cheese ',
#         'other vegetables', 'canned beer', 'brown bread'], dtype=object),
#  array(['root vegetables', 'ham', 'butter', 'brown bread', 'pastry',
#         'spread cheese'], dtype=object),
#  array(['root vegetables', 'sweet spreads'], dtype=object),
#  array(['beef', 'whole milk', 'newspapers'], dtype=object),
#  array(['beef', 'whole milk', 'frozen meals'], dtype=object),
#  array(['pip fruit', 'specialty bar', 'chocolate'], dtype=object),
#  array(['frankfurter', 'canned beer'], dtype=object),
#  array(['ice cream', 'chewing gum'], dtype=object),
#  array(['soda', 'butter'], dtype=object),
#  array(['soda', 'detergent'], dtype=object),
#  array(['white bread', 'domestic eggs'], dtype=object),
#  array(['other vegetables', 'whole milk', 'canned fruit'], dtype=object),
#  array(['soda'], dtype=object),
#  array(['citrus fruit', 'domestic eggs'], dtype=object),
#  array(['other vegetables', 'onions', 'shopping bags'], dtype=object),
#  array(['butter milk', 'cleaner', 'bottled water'], dtype=object),
#  array(['whole milk', 'rolls/buns', 'soda'], dtype=object),
#  array(['other vegetables', 'bottled beer'], dtype=object),
#  array(['bottled beer', 'sliced cheese'], dtype=object),
#  array(['tropical fruit', 'dessert'], dtype=object),
#  array(['whipped/sour cream', 'specialty chocolate'], dtype=object),
#  array(['root vegetables'], dtype=object),
#  array(['pip fruit', 'rolls/buns', 'soda'], dtype=object),
#  array(['bottled water', 'soda'], dtype=object),
#  array(['hamburger meat', 'bottled beer'], dtype=object),
#  array(['other vegetables', 'meat spreads'], dtype=object),
#  array(['canned beer', 'root vegetables'], dtype=object),
#  array(['sparkling wine', 'waffles'], dtype=object),
#  array(['hamburger meat', 'citrus fruit', 'specialty chocolate',
#         'other vegetables'], dtype=object),
#  array(['berries', 'white bread'], dtype=object),
#  array(['butter', 'seasonal products', 'fruit/vegetable juice'],
#        dtype=object),
#  array(['brown bread', 'pastry'], dtype=object),
#  array(['citrus fruit', 'root vegetables'], dtype=object),
#  array(['soda', 'shopping bags'], dtype=object),
#  array(['butter', 'coffee', 'soda', 'pastry'], dtype=object),
#  array(['whole milk', 'bottled water', 'honey'], dtype=object),
#  array(['pip fruit', 'napkins'], dtype=object),
#  array(['finished products', 'liquor'], dtype=object),
#  array(['butter', 'shopping bags'], dtype=object),
#  array(['whole milk', 'soft cheese'], dtype=object),
#  array(['domestic eggs', 'newspapers'], dtype=object),
#  array(['pip fruit', 'shopping bags'], dtype=object),
#  array(['mayonnaise', 'candy', 'rolls/buns', 'bottled beer'], dtype=object),
#  array(['whole milk', 'brown bread'], dtype=object),
#  array(['beef', 'whipped/sour cream'], dtype=object),
#  array(['sausage', 'chocolate'], dtype=object),
#  array(['pip fruit', 'waffles'], dtype=object),
#  array(['root vegetables', 'citrus fruit', 'misc. beverages',
#         'sliced cheese', 'packaged fruit/vegetables', 'yogurt',
#         'whipped/sour cream'], dtype=object),
#  array(['citrus fruit', 'yogurt'], dtype=object),
#  array(['citrus fruit', 'napkins'], dtype=object),
#  array(['frozen fish', 'specialty chocolate'], dtype=object),
#  array(['other vegetables', 'specialty chocolate', 'newspapers'],
#        dtype=object),
#  array(['beverages', 'sausage'], dtype=object),
#  array(['sugar', 'canned vegetables', 'flour', 'bottled water',
#         'salty snack'], dtype=object),
#  array(['rolls/buns', 'whole milk', 'white bread', 'popcorn'], dtype=object),
#  array(['grapes', 'rolls/buns'], dtype=object),
#  array(['citrus fruit', 'root vegetables'], dtype=object),
#  array(['candy', 'dessert', 'rolls/buns', 'canned fish'], dtype=object),
#  array(['brown bread', 'detergent'], dtype=object),
#  array(['candles', 'whole milk'], dtype=object),
#  array(['misc. beverages', 'coffee'], dtype=object),
#  array(['coffee', 'oil'], dtype=object),
#  array(['yogurt', 'rolls/buns'], dtype=object),
#  array(['soda', 'curd cheese', 'root vegetables', 'semi-finished bread'],
#        dtype=object),
#  array(['yogurt', 'roll products '], dtype=object),
#  array(['grapes', 'chicken', 'bottled beer', 'root vegetables'],
#        dtype=object),
#  array(['softener', 'chocolate'], dtype=object),
#  array(['soda', 'beverages'], dtype=object),
#  array(['root vegetables', 'yogurt'], dtype=object),
#  array(['rolls/buns', 'pastry'], dtype=object),
#  array(['sliced cheese', 'pip fruit'], dtype=object),
#  array(['whole milk', 'waffles'], dtype=object),
#  array(['white bread', 'bottled water', 'ready soups', 'curd'],
#        dtype=object),
#  array(['yogurt', 'whole milk', 'chewing gum'], dtype=object),
#  array(['whole milk', 'oil'], dtype=object),
#  array(['sausage', 'cat food'], dtype=object),
#  array(['tropical fruit', 'hygiene articles', 'candles'], dtype=object),
#  array(['pastry', 'sausage', 'soda', 'rolls/buns', 'sugar',
#         'other vegetables', 'whole milk', 'softener'], dtype=object),
#  array(['whole milk', 'yogurt', 'semi-finished bread'], dtype=object),
#  array(['frankfurter', 'whole milk'], dtype=object),
#  array(['ham', 'pickled vegetables', 'shopping bags'], dtype=object),
#  array(['soft cheese', 'bottled water'], dtype=object),
#  array(['tropical fruit', 'butter milk'], dtype=object),
#  array(['rolls/buns', 'frozen meals'], dtype=object),
#  array(['shopping bags', 'misc. beverages'], dtype=object),
#  array(['pork', 'beef', 'yogurt'], dtype=object),
#  array(['sausage', 'dessert'], dtype=object),
#  array(['yogurt', 'shopping bags'], dtype=object),
#  array(['fruit/vegetable juice', 'long life bakery product',
#         'specialty cheese'], dtype=object),
#  array(['ham', 'brown bread'], dtype=object),
#  array(['butter', 'margarine'], dtype=object),
#  array(['frankfurter', 'butter', 'specialty bar', 'yogurt'], dtype=object),
#  array(['finished products', 'domestic eggs'], dtype=object),
#  array(['specialty bar', 'whole milk'], dtype=object),
#  array(['UHT-milk', 'other vegetables'], dtype=object),
#  array(['rolls/buns', 'tropical fruit', 'salty snack', 'specialty bar'],
#        dtype=object),
#  array(['tropical fruit', 'salt'], dtype=object),
#  array(['tropical fruit', 'cat food'], dtype=object),
#  array(['beef', 'domestic eggs'], dtype=object),
#  array(['root vegetables', 'other vegetables'], dtype=object),
#  array(['chicken', 'beef', 'pork', 'newspapers', 'dessert', 'margarine',
#         'brown bread'], dtype=object),
#  array(['domestic eggs', 'fruit/vegetable juice'], dtype=object),
#  array(['citrus fruit', 'bottled beer'], dtype=object),
#  array(['syrup', 'waffles'], dtype=object),
#  array(['meat', 'chicken', 'yogurt', 'pip fruit'], dtype=object),
#  array(['pip fruit', 'other vegetables', 'semi-finished bread',
#         'sliced cheese'], dtype=object),
#  array(['sauces', 'yogurt'], dtype=object),
#  array(['grapes', 'root vegetables', 'shopping bags'], dtype=object),
#  array(['turkey', 'onions'], dtype=object),
#  array(['citrus fruit', 'long life bakery product'], dtype=object),
#  array(['canned beer', 'brown bread'], dtype=object),
#  array(['whole milk', 'soda', 'root vegetables', 'pastry', 'specialty fat',
#         'bottled water', 'napkins', 'tropical fruit'], dtype=object),
#  array(['citrus fruit', 'grapes', 'bottled water'], dtype=object),
#  array(['whole milk', 'dog food', 'pastry'], dtype=object),
#  array(['whole milk', 'sugar'], dtype=object),
#  array(['whole milk', 'sausage', 'yogurt', 'butter'], dtype=object),
#  array(['pork', 'frozen meals'], dtype=object),
#  array(['citrus fruit'], dtype=object),
#  array(['other vegetables', 'fruit/vegetable juice'], dtype=object),
#  array(['tropical fruit', 'rolls/buns', 'frozen fish'], dtype=object),
#  array(['meat', 'cling film/bags', 'curd'], dtype=object),
#  array(['tropical fruit', 'meat', 'whole milk', 'candles'], dtype=object),
#  array(['canned beer', 'brown bread'], dtype=object),
#  array(['red/blush wine', 'instant coffee'], dtype=object),
#  array(['canned beer', 'margarine', 'chocolate'], dtype=object),
#  array(['pastry', 'waffles'], dtype=object),
#  array(['rolls/buns', 'specialty chocolate', 'napkins', 'onions', 'rice',
#         'butter milk', 'dental care'], dtype=object),
#  array(['sausage', 'pasta'], dtype=object),
#  array(['frankfurter', 'ice cream'], dtype=object),
#  array(['sugar', 'bottled water'], dtype=object),
#  array(['canned beer', 'coffee'], dtype=object),
#  array(['condensed milk', 'onions'], dtype=object),
#  array(['citrus fruit', 'butter', 'UHT-milk'], dtype=object),
#  array(['citrus fruit', 'semi-finished bread', 'yogurt'], dtype=object),
#  array(['packaged fruit/vegetables', 'flour'], dtype=object),
#  array(['ham', 'rum'], dtype=object),
#  array(['sausage', 'specialty chocolate'], dtype=object),
#  array(['UHT-milk', 'cooking chocolate'], dtype=object),
#  array(['pastry', 'rolls/buns'], dtype=object),
#  array(['whole milk', 'curd'], dtype=object),
#  array(['white bread', 'jam'], dtype=object),
#  array(['photo/film', 'brown bread'], dtype=object),
#  array(['shopping bags', 'whole milk', 'detergent', 'flour'], dtype=object),
#  array(['dessert', 'sliced cheese', 'bottled beer', 'other vegetables'],
#        dtype=object),
#  array(['butter milk', 'soda', 'seasonal products'], dtype=object),
#  array(['beef', 'citrus fruit', 'specialty bar', 'white bread', 'soda',
#         'vinegar', 'long life bakery product', 'domestic eggs'],
#        dtype=object),
#  array(['hard cheese', 'pastry'], dtype=object),
#  array(['yogurt', 'whipped/sour cream'], dtype=object),
#  array(['photo/film', 'beverages', 'bottled beer'], dtype=object),
#  array(['beef', 'white bread', 'frozen potato products'], dtype=object),
#  array(['ham', 'whipped/sour cream', 'newspapers'], dtype=object),
#  array(['mustard', 'brown bread'], dtype=object),
#  array(['whole milk', 'other vegetables'], dtype=object),
#  array(['canned beer', 'sliced cheese'], dtype=object),
#  array(['soda', 'canned beer'], dtype=object),
#  array(['ham', 'domestic eggs'], dtype=object),
#  array(['frankfurter', 'pastry', 'misc. beverages'], dtype=object),
#  array(['soda', 'butter milk'], dtype=object),
#  array(['sausage', 'root vegetables'], dtype=object),
#  array(['white wine', 'photo/film', 'whipped/sour cream'], dtype=object),
#  array(['hard cheese', 'soda'], dtype=object),
#  array(['ice cream', 'onions'], dtype=object),
#  array(['pork', 'sliced cheese', 'flour'], dtype=object),
#  array(['grapes', 'detergent'], dtype=object),
#  array(['yogurt', 'margarine'], dtype=object),
#  array(['butter', 'grapes', 'bottled water'], dtype=object),
#  array(['pasta', 'canned beer'], dtype=object),
#  array(['rolls/buns', 'bottled beer'], dtype=object),
#  array(['UHT-milk', 'curd'], dtype=object),
#  array(['whipped/sour cream', 'shopping bags'], dtype=object),
#  array(['butter milk', 'other vegetables'], dtype=object),
#  array(['rolls/buns', 'whipped/sour cream', 'waffles', 'margarine', 'soda',
#         'salty snack', 'canned beer'], dtype=object),
#  array(['other vegetables', 'rolls/buns'], dtype=object),
#  array(['chicken', 'whole milk'], dtype=object),
#  array(['curd', 'pastry'], dtype=object),
#  array(['yogurt', 'shopping bags', 'coffee'], dtype=object),
#  array(['root vegetables', 'margarine', 'bottled water'], dtype=object),
#  array(['salty snack', 'root vegetables'], dtype=object),
#  array(['sausage', 'bottled beer', 'spread cheese'], dtype=object),
#  array(['bottled water', 'soda'], dtype=object),
#  array(['condensed milk', 'other vegetables'], dtype=object),
#  array(['dog food', 'processed cheese'], dtype=object),
#  array(['canned beer', 'bottled beer'], dtype=object),
#  array(['other vegetables', 'curd', 'abrasive cleaner'], dtype=object),
#  array(['butter', 'roll products '], dtype=object),
#  array(['shopping bags', 'waffles'], dtype=object),
#  array(['whole milk', 'cling film/bags'], dtype=object),
#  array(['newspapers', 'pip fruit', 'dishes'], dtype=object),
#  array(['rolls/buns', 'hard cheese'], dtype=object),
#  array(['ham', 'whole milk', 'other vegetables', 'soda', 'white bread',
#         'tropical fruit', 'sugar'], dtype=object),
#  array(['citrus fruit', 'other vegetables'], dtype=object),
#  array(['beverages', 'sugar'], dtype=object),
#  array(['cleaner', 'misc. beverages'], dtype=object),
#  array(['pork', 'other vegetables', 'cream cheese '], dtype=object),
#  array(['butter milk', 'hard cheese'], dtype=object),
#  array(['frankfurter', 'margarine'], dtype=object),
#  array(['whipped/sour cream', 'yogurt'], dtype=object),
#  array(['roll products ', 'waffles'], dtype=object),
#  array(['meat', 'soda'], dtype=object),
#  array(['sausage', 'processed cheese'], dtype=object),
#  array(['condensed milk', 'whole milk'], dtype=object),
#  array(['finished products', 'yogurt', 'bottled beer', 'bottled water'],
#        dtype=object),
#  array(['brown bread', 'tropical fruit'], dtype=object),
#  array(['frozen vegetables', 'sausage', 'whole milk', 'rolls/buns',
#         'other vegetables', 'oil', 'frozen fish', 'baking powder'],
#        dtype=object),
#  array(['onions', 'hard cheese'], dtype=object),
#  array(['soda', 'shopping bags'], dtype=object),
#  array(['oil', 'margarine'], dtype=object),
#  array(['whole milk', 'specialty cheese'], dtype=object),
#  array(['specialty chocolate', 'pasta', 'soda', 'long life bakery product'],
#        dtype=object),
#  array(['meat', 'other vegetables', 'pasta'], dtype=object),
#  array(['citrus fruit', 'other vegetables'], dtype=object),
#  array(['sausage', 'dog food', 'bottled beer', 'bottled water'],
#        dtype=object),
#  array(['beverages', 'sugar', 'pasta', 'domestic eggs'], dtype=object),
#  array(['shopping bags', 'tropical fruit'], dtype=object),
#  array(['butter', 'chocolate'], dtype=object),
#  array(['sausage', 'frozen meals'], dtype=object),
#  array(['soda', 'cling film/bags'], dtype=object),
#  array(['UHT-milk', 'soft cheese'], dtype=object),
#  array(['candy', 'soda'], dtype=object),
#  array(['rolls/buns', 'salty snack', 'bottled water', 'shopping bags'],
#        dtype=object),
#  array(['dessert', 'condensed milk', 'rolls/buns', 'shopping bags'],
#        dtype=object),
#  array(['turkey', 'shopping bags'], dtype=object),
#  array(['tropical fruit', 'rolls/buns'], dtype=object),
#  array(['onions', 'soft cheese'], dtype=object),
#  array(['grapes', 'other vegetables'], dtype=object),
#  array(['soda', 'canned fruit', 'processed cheese', 'shopping bags'],
#        dtype=object),
#  array(['coffee', 'white bread'], dtype=object),
#  array(['yogurt', 'canned beer'], dtype=object),
#  array(['whipped/sour cream', 'yogurt'], dtype=object),
#  array(['tropical fruit', 'berries'], dtype=object),
#  array(['other vegetables', 'UHT-milk'], dtype=object),
#  array(['frozen vegetables', 'other vegetables'], dtype=object),
#  array(['butter', 'candy'], dtype=object),
#  array(['chicken', 'butter'], dtype=object),
#  array(['citrus fruit', 'skin care'], dtype=object),
#  array(['root vegetables', 'frozen vegetables'], dtype=object),
#  array(['tropical fruit', 'pip fruit'], dtype=object),
#  array(['frankfurter', 'whole milk'], dtype=object),
#  array(['dessert', 'packaged fruit/vegetables'], dtype=object),
#  array(['margarine'], dtype=object),
#  array(['beef', 'curd'], dtype=object),
#  array(['citrus fruit', 'coffee'], dtype=object),
#  array(['soda', 'frozen meals', 'bottled beer'], dtype=object),
#  array(['other vegetables', 'chewing gum'], dtype=object),
#  array(['canned beer', 'dessert', 'fruit/vegetable juice'], dtype=object),
#  array(['chicken', 'pastry'], dtype=object),
#  array(['pork', 'turkey', 'pot plants', 'whole milk', 'soda', 'dishes'],
#        dtype=object),
#  array(['grapes', 'other vegetables'], dtype=object),
#  array(['pastry', 'liqueur'], dtype=object),
#  array(['sausage', 'processed cheese', 'baking powder', 'specialty cheese'],
#        dtype=object),
#  array(['ham', 'napkins'], dtype=object),
#  array(['white wine', 'specialty bar', 'specialty chocolate'], dtype=object),
#  array(['soda', 'red/blush wine'], dtype=object),
#  array(['sausage', 'coffee'], dtype=object),
#  array(['berries', 'domestic eggs'], dtype=object),
#  array(['sugar', 'other vegetables'], dtype=object),
#  array(['tea', 'coffee'], dtype=object),
#  array(['UHT-milk', 'herbs', 'butter', 'oil'], dtype=object),
#  array(['rolls/buns', 'yogurt'], dtype=object),
#  array(['frozen dessert', 'cream cheese '], dtype=object),
#  array(['yogurt', 'coffee'], dtype=object),
#  array(['rolls/buns', 'fruit/vegetable juice', 'frozen vegetables',
#         'whipped/sour cream'], dtype=object),
#  array(['hamburger meat', 'coffee'], dtype=object),
#  array(['whole milk', 'shopping bags'], dtype=object),
#  array(['ice cream', 'whole milk'], dtype=object),
#  array(['sausage', 'grapes', 'sliced cheese', 'napkins'], dtype=object),
#  array(['fruit/vegetable juice', 'berries'], dtype=object),
#  array(['pork', 'root vegetables'], dtype=object),
#  array(['pip fruit', 'shopping bags'], dtype=object),
#  array(['sausage', 'curd'], dtype=object),
#  array(['whole milk', 'domestic eggs', 'canned vegetables',
#         'flower (seeds)'], dtype=object),
#  array(['rolls/buns', 'hard cheese', 'flour'], dtype=object),
#  array(['organic sausage', 'frozen meals', 'sugar'], dtype=object),
#  array(['whole milk', 'onions', 'pickled vegetables'], dtype=object),
#  array(['citrus fruit', 'other vegetables'], dtype=object),
#  array(['frozen meals', 'bottled beer'], dtype=object),
#  array(['tropical fruit', 'yogurt', 'semi-finished bread', 'soda'],
#        dtype=object),
#  array(['tropical fruit', 'white bread', 'butter'], dtype=object),
#  array(['specialty bar', 'tropical fruit'], dtype=object),
#  array(['bottled water', 'pastry'], dtype=object),
#  array(['sugar', 'curd'], dtype=object),
#  array(['sausage', 'other vegetables', 'tropical fruit', 'mayonnaise'],
#        dtype=object),
#  array(['other vegetables', 'whole milk', 'soda'], dtype=object),
#  array(['pork', 'brown bread'], dtype=object),
#  array(['UHT-milk', 'canned fish', 'root vegetables', 'waffles'],
#        dtype=object),
#  array(['cream cheese ', 'pip fruit', 'citrus fruit', 'chicken',
#         'other vegetables', 'curd', 'specialty chocolate', 'pastry'],
#        dtype=object),
#  array(['pork', 'yogurt'], dtype=object),
#  array(['hamburger meat', 'other vegetables', 'domestic eggs'],
#        dtype=object),
#  array(['shopping bags', 'tropical fruit', 'red/blush wine'], dtype=object),
#  array(['other vegetables', 'sliced cheese'], dtype=object),
#  array(['butter', 'whole milk'], dtype=object),
#  array(['oil', 'canned fish'], dtype=object),
#  array(['whole milk', 'misc. beverages'], dtype=object),
#  array(['white wine', 'sauces'], dtype=object),
#  array(['other vegetables', 'margarine', 'brown bread'], dtype=object),
#  array(['red/blush wine', 'frozen meals', 'canned fruit'], dtype=object),
#  array(['other vegetables', 'liquor', 'whole milk', 'butter milk'],
#        dtype=object),
#  array(['rolls/buns', 'seasonal products'], dtype=object),
#  array(['tropical fruit', 'root vegetables'], dtype=object),
#  array(['other vegetables', 'whole milk', 'softener'], dtype=object),
#  array(['citrus fruit', 'cereals'], dtype=object),
#  array(['cake bar', 'flower soil/fertilizer'], dtype=object),
#  array(['pork', 'napkins'], dtype=object),
#  array(['specialty bar', 'cleaner'], dtype=object),
#  array(['artif. sweetener', 'whole milk'], dtype=object),
#  array(['pork', 'pastry'], dtype=object),
#  array(['coffee', 'other vegetables', 'specialty cheese'], dtype=object),
#  array(['dessert', 'rolls/buns'], dtype=object),
#  array(['tidbits', 'cream cheese '], dtype=object),
#  array(['curd', 'hygiene articles'], dtype=object),
#  array(['rolls/buns', 'dental care'], dtype=object),
#  array(['root vegetables', 'butter', 'dessert'], dtype=object),
#  array(['citrus fruit', 'pastry'], dtype=object),
#  array(['salt', 'citrus fruit'], dtype=object),
#  array(['other vegetables', 'whole milk'], dtype=object),
#  array(['sausage', 'onions', 'mustard'], dtype=object),
#  array(['frozen potato products', 'domestic eggs', 'shopping bags',
#         'butter milk'], dtype=object),
#  array(['white bread', 'specialty chocolate'], dtype=object),
#  array(['ice cream', 'butter'], dtype=object),
#  array(['dessert', 'house keeping products'], dtype=object),
#  array(['condensed milk', 'hard cheese'], dtype=object),
#  array(['hard cheese', 'yogurt'], dtype=object),
#  array(['sausage', 'whole milk', 'rolls/buns', 'bottled beer'],
#        dtype=object),
#  array(['whole milk', 'cream cheese ', 'semi-finished bread'], dtype=object),
#  array(['sausage', 'rolls/buns'], dtype=object),
#  array(['frankfurter', 'shopping bags'], dtype=object),
#  array(['photo/film', 'whole milk', 'yogurt', 'white bread', 'pot plants',
#         'dessert'], dtype=object),
#  ...]

# %% [markdown]
# ## Encode the lists
#
# Use the [`TransactionEncoder` method](http://rasbt.github.io/mlxtend/user_guide/preprocessing/TransactionEncoder/) from `mlxtend` to encode our list of lists into a matrix of presence/absence Boolean values.  See the example at the link above.
#
# Once you do that, we can re-convert the output into a DataFrame by creating a dataframe based on the output and the value in the TransactionEncoder's `column_` attribute.  Again, see the link above.  It shows how to do this.

# %%
te = TransactionEncoder()
encoded_itemset = te.fit(list_trans).transform(list_trans)
encoded_itemset
encoded_itemset.shape
te.columns_

df_encoded = pd.DataFrame(encoded_itemset,columns=te.columns_)
df_encoded.head()


milk_items = list(filter(lambda x: "MILK" in x.upper(),te.columns_))
milk_items

small_items = list(filter(lambda x: len(x) < 3, te.columns_))
small_items

df_encoded = df_encoded.drop(columns=small_items)
df_encoded
len(df_encoded.columns)

print('How many unique itmes are left?',len(df_encoded.columns))
# Out:
# How many unique itmes are left? 167

# %% [markdown]
# ## Use `apriori` to get support
#
# The input to the association rule generator is a data frame that contains support for each transaction.  The [`aprori`](http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/) module will do this for us.  See the link for documentation.
#
# Let's use
#
#     min_support=0.001  # All transactions that are > 1:1000

# %%
# Before we begin, let's do a small
# amount of cleanup.  Let's remove all
# columns (items) that have a name less
# than three letters.  Use the Pandas
# drop method to perform this action.
small_items = list(filter(lambda x: len(x) < 3, te.columns_))

df_encoded = df_encoded.drop(columns=small_items)

print('How many unique itmes are left?',len(df_encoded.columns))
# Out:
# How many unique itmes are left? 167

# %%
# Use apriori to create a dataframe with columns
# of support and itemset lists
df_support = apriori(df_encoded, min_support=0.001,use_colnames=True)
df_support.sort_values('support', inplace=True,ascending=False)
df_support
# Out:
#       support                   itemsets
# 146  0.157923               (whole milk)
# 90   0.122101         (other vegetables)
# 109  0.110005               (rolls/buns)
# 123  0.097106                     (soda)
# 147  0.085879                   (yogurt)
# ..        ...                        ...
# 344  0.001002       (margarine, chicken)
# 201  0.001002    (chicken, bottled beer)
# 202  0.001002  (chocolate, bottled beer)
# 516  0.001002   (pastry, hamburger meat)
# 256  0.001002      (butter, brown bread)
#
# [750 rows x 2 columns]

# %% [markdown]
# ## Use association_rules to find the rules
#
# Using the dataframe generated by `apriori`, find the association rules with the greatest lift.  See the [association_rules documentation](https://rasbt.github.io/mlxtend/api_modules/mlxtend.frequent_patterns/association_rules/) for how to do this.
#
# Sort the resulting DataFrame by lift in descending order.  A lift > 1 indicates that the items are often purchased together and that buying X will increase the purchase of Y.  A lift of < 1 indicates the items are often substituted.  That is X is substituted for Y so X and Y don't appear together often.
#
# Examine the resulting DataFrame.  For the association rule X -> Y, X is the column `antecedents` and Y is the column `consequents`.  If sorted you can see the metrics for each rule based upon the lift.

# %%
# Find the association rules
rules = association_rules(df_support, metric='lift',min_threshold=1.0)

rules.sort_values('lift', ascending=False, inplace=True)

len(rules)
# Out:
# 240

# %%
# Sort the rules by lift
# and examine the output
# to find what rules were
# discovered
